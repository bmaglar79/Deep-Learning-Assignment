# %%
import time
import os
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense

# %%
COL_NAME_CEMENT = "Cement"
COL_NAME_BLAST_FURNACE_SLAG = "Blast Furnace Slag"
COL_NAME_FLY_ASH = "Fly Ash"
COL_NAME_WATER = "Water"
COL_NAME_SUPERPLASTICIZER = "Superplasticizer"
COL_NAME_COARSE_AGGREGATE = "Coarse Aggregate"
COL_NAME_FINE_AGGREGATE = "Fine Aggregate"
COL_NAME_AGE = "Age"
COL_NAME_STRENGTH = "Strength"

COL_NAME_EXPERIMENT = "Experiment"
COL_NAME_MSE = "Mean MSE"
COL_NAME_RMSE = "Std Deviation MSE"

# This dataframe contains three columns: 
# name_of_experiments, mse, rmse
header_of_df_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
df_mse_and_rmse = pd.DataFrame(columns=header_of_df_mse_and_rmse, data=[])


def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)


def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None


def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None
def build_model_with_one_hidden_layer(num_of_features=3):
    """ Building baseline model that contains:

    + One hidden layer of 10 nodes, and a ReLU activation function.
    + Use the adam optimizer and the mean squared error as the loss function.
    """    
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(num_of_features,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model


def build_model_with_three_hidden_layers(num_of_features=3):
    """ Building model that contains:
    
    + Three hidden layers, each of 10 nodes and ReLU activation function.    
    + Use the adam optimizer and the mean squared error as the loss function.
    """
    
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(num_of_features,)))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn.    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Note that: given model which is compiled
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse


def get_report(name_of_experiment, mean_mse, std_mse):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """
    values = [[name_of_experiment, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_df_mse_and_rmse, data=values)

# %%
file_input_path = "concrete_data.csv"

# %%
if os.path.exists(file_input_path):
    print("We will load the data from file '{}' to dataframe.".format(file_input_path))
    df = pd.read_csv(file_input_path, header=0)
else:
    print("File not found : {}".format(file_input_path))
    df = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
# Out:
# We will load the data from file 'concrete_data.csv' to dataframe.

# %%
df.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
print("(row, column) = {}".format(df.shape))
# Out:
# (row, column) = (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# ## Normalizing Input Data

# %%
list_of_column_names = df.columns
list_of_column_names
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %% [markdown]
# ## Splitting predictors and target

# %%
list_of_col_names_predictors = [x for x in list_of_column_names 
                                if x != COL_NAME_STRENGTH]

# %%
list_of_col_names_predictors
# Out:
# ['Cement',
#  'Blast Furnace Slag',
#  'Fly Ash',
#  'Water',
#  'Superplasticizer',
#  'Coarse Aggregate',
#  'Fine Aggregate',
#  'Age']

# %%
df_predictors = df[list_of_col_names_predictors]

# %%
df_target = df[[COL_NAME_STRENGTH]]

# %%
df_predictors.head(3)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270

# %%
df_target.head(3)
# Out:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27

# %% [markdown]
# ## Applying normalizing method

# %%
df_predictors_norm = (df_predictors - df_predictors.mean())/df_predictors.std()

# %%
df_predictors_norm.head(3)
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340

# %% [markdown]
# ## Building and Training with baseline model

# %%
num_of_features = len(df.columns) - 1
print("Number of features for input layer : ", num_of_features)
# Out:
# Number of features for input layer :  8

# %%
max_iteration = 50
epochs = 50
verbose = 0

# Get the compiled model
model = build_model_with_one_hidden_layer(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(df_predictors, 
                                            df_target, 
                                            model, 
                                            max_iteration=max_iteration, 
                                            epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3918001651763916
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8207714557647705
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9384942054748535
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8003332614898682
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8796916007995605
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8191218376159668
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8193187713623047
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.7545304298400879
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8312852382659912
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8872177600860596
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.7813985347747803
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9352169036865234
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8674530982971191
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8486242294311523
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8292784690856934
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.7493298053741455
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8338770866394043
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0433216094970703
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8749904632568359
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8113100528717041
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8102924823760986
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.1624772548675537
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.971503734588623
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9365224838256836
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9055273532867432
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.880518913269043
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8696293830871582
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8404638767242432
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8462216854095459
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8587121963500977
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9518251419067383
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.000291347503662
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.232280969619751
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9382510185241699
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8767132759094238
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9236199855804443
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0022501945495605
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9672257900238037
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.869563102722168
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9571447372436523
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9372339248657227
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8660707473754883
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8595626354217529
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8447082042694092
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8031373023986816
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9336540699005127
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8516185283660889
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8632793426513672
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8507273197174072
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9042677879333496
# Finished - 50 times.
# And the list of mean squared errors : [722.7792718774019, 210.42103710657454, 121.83092427578536, 86.6749354538319, 68.79503257727528, 59.61513138920477, 53.89806654737628, 55.783749266881266, 54.4741046641861, 51.23564084698772, 56.24290309545755, 58.48566701411586, 62.427278211538784, 50.3591276132393, 56.915254906319895, 49.98741230629482, 47.732839504927945, 50.76109948934533, 48.990724916984576, 48.888501193989825, 48.11210206712681, 48.64192638430924, 47.794011331090694, 48.28084846260144, 49.03816784166099, 57.030550651566806, 49.790471228504934, 47.81295844149492, 55.113529796789784, 52.68405602823459, 55.69989322510771, 48.070798782572325, 47.50116045624647, 47.878228887786236, 48.79225174499198, 47.78232112185331, 49.298724204412366, 47.51481140094744, 57.501806807486936, 50.33962484244285, 49.62866249182279, 47.76874374185758, 46.658159857627275, 45.703839776091236, 45.68376894901353, 52.27963434099089, 46.15340653497731, 45.711893723261774, 57.37880255613386, 45.67842212133351]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 70.07 and 96.53, respectively

# %% [markdown]
# ## Mean and Standard deviation on mean squared error

# %%
name_of_experiment = "Baseline-Raw (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
df_result_baseline
# Out:
#                  Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-Raw (50 epochs)     70.07              96.53

# %%
# Concat baseline dataframe into result
df_mse_and_rmse = pd.concat([df_mse_and_rmse, df_result_baseline], axis=0)

# Review the result dataframe
df_mse_and_rmse.reset_index(drop=True)
# Out:
#                  Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-Raw (50 epochs)     70.07              96.53

# %% [markdown]
# ## B - Experiment with Normalized data

# %%
#Before normalization
df_predictors.head(3)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270

# %%
#After normalization
df_predictors_norm.head(3)
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340

# %% [markdown]
# ## Building and Training with the baseline model after normalizing the data with 50 epochs

# %%
max_iteration = 50
epochs = 50
verbose = 0

# Get the compiled model
model = build_model_with_one_hidden_layer(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(df_predictors_norm, 
                                            df_target, 
                                            model, 
                                            max_iteration=max_iteration, 
                                            epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0679576396942139
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9514567852020264
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9589664936065674
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9689643383026123
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8818895816802979
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9548687934875488
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9055538177490234
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0890512466430664
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0131161212921143
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0132956504821777
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0389792919158936
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9239604473114014
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9338564872741699
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9932806491851807
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8211581707000732
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.866478681564331
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8843948841094971
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9073128700256348
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8985013961791992
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8587710857391357
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8602278232574463
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8311147689819336
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8531146049499512
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9398536682128906
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8612124919891357
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8122096061706543
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8062553405761719
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8977289199829102
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8899383544921875
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9466180801391602
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8267853260040283
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8047208786010742
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9357993602752686
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.925285816192627
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8796052932739258
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8385903835296631
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8669493198394775
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9274888038635254
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9086477756500244
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8697471618652344
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9030225276947021
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8608360290527344
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9360971450805664
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.875267744064331
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9088623523712158
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8682608604431152
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8677258491516113
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.858684778213501
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8986110687255859
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8659780025482178
# Finished - 50 times.
# And the list of mean squared errors : [448.1298641831093, 165.0906672886689, 99.9288939135719, 82.03527584868544, 71.12817304619027, 64.98579024909361, 54.78702007957995, 45.253005416951574, 41.89121032929724, 40.5757352476864, 39.729938675972264, 39.383352288239315, 38.97305740803072, 38.60409627730183, 38.62819792937364, 38.274306317211, 38.15393792450878, 38.08011218666414, 37.61599286955382, 37.13619692420011, 36.701796815893644, 36.42336518695398, 36.21315426479657, 35.77377584497552, 35.61243730460668, 35.31130455916454, 35.08814489411457, 34.95253274062164, 34.57975851265589, 34.509714705778, 34.55082559048882, 34.20134340861462, 33.79171106578153, 33.750695086249216, 33.6268578505445, 33.37682714493843, 33.37751397264524, 33.16986243061362, 33.120980787302614, 32.959728306494924, 32.79098687100596, 32.66897787431548, 32.53384814750327, 32.615692632880425, 32.454418658808635, 32.445171396482166, 32.34312292480973, 32.41835286731656, 32.21801383096849, 32.21320583296611]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 50.28 and 60.88, respectively

# %% [markdown]
# ## Mean and Standard deviation on mean squared error

# %%
name_of_experiment = "Normalized-1 Hidden Layers(50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
df_result_baseline
# Out:
#                               Experiment  Mean MSE  Std Deviation MSE
# 0  Normalized-1 Hidden Layers(50 epochs)     50.28              60.88

# %%
# Concat baseline dataframe into result
df_mse_and_rmse = pd.concat([df_mse_and_rmse, df_result_baseline], axis=0)

# Review the result dataframe
df_mse_and_rmse.reset_index(drop=True)
# Out:
#                               Experiment  Mean MSE  Std Deviation MSE
# 0               Baseline-Raw (50 epochs)     70.07              96.53
# 1  Normalized-1 Hidden Layers(50 epochs)     50.28              60.88

# %% [markdown]
# ## C. Increate the number of epochs

# %% [markdown]
# ## Building and Training with the baseline model after normalizing the data with 100 epochs

# %%
max_iteration = 50
epochs = 100
verbose = 0

# Get the compiled model
model = build_model_with_one_hidden_layer(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(df_predictors_norm, 
                                            df_target, 
                                            model, 
                                            max_iteration=max_iteration, 
                                            epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.854759931564331
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8492217063903809
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.74550199508667
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7516765594482422
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7615890502929688
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.886814832687378
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7330639362335205
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7972044944763184
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7087953090667725
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6495778560638428
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7155213356018066
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.715442180633545
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8138787746429443
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6838786602020264
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5909807682037354
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6744940280914307
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7581417560577393
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7494711875915527
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.0587313175201416
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9520750045776367
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.197134494781494
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9599919319152832
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8327040672302246
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.0086004734039307
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.852877140045166
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6999084949493408
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5900673866271973
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7207443714141846
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.69614577293396
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7002108097076416
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5331764221191406
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7052507400512695
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7106642723083496
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8376634120941162
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7521111965179443
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.705723524093628
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.720038890838623
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8629562854766846
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.586456298828125
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.681830644607544
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.818504810333252
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7931439876556396
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5622358322143555
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.60746169090271
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.625398874282837
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6332547664642334
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.57027268409729
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6649587154388428
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.774498701095581
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7289631366729736
# Finished - 50 times.
# And the list of mean squared errors : [144.25652970667838, 79.28651133467281, 50.332928722366084, 45.8435918060155, 44.333231907999625, 43.33063296865439, 42.792826725533125, 42.24041273033502, 41.689290074395736, 41.4568905503724, 41.17657563955705, 40.904347700095535, 40.68880757999574, 40.44150777215147, 40.15775871419932, 39.77453016459251, 39.549057047791315, 39.54167199898961, 39.48610253832985, 39.58439350389666, 39.445248566375916, 39.380870760341566, 39.39200167149994, 39.52722494346576, 39.44724951853648, 39.392252145874714, 39.26769549023121, 39.24793107224257, 39.146629244804615, 39.19738116763186, 39.267439460874414, 39.08656508684301, 39.14217620796269, 39.14682392563865, 39.10109038227081, 39.00655274457931, 39.10443767023295, 38.94758677747392, 39.16178382194124, 39.04098345954832, 39.23235312410099, 39.12278654780149, 39.11684684449174, 39.23732948199014, 38.9941119768424, 39.13355810298712, 39.051845148567736, 39.13486726414913, 38.88962135525502, 39.072293641323895]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 43.05 and 15.6, respectively

# %%
ame_of_experiment = "Normalized-1 Hidden Layers(100 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
df_result_baseline
# Out:
#                               Experiment  Mean MSE  Std Deviation MSE
# 0  Normalized-1 Hidden Layers(50 epochs)     43.05               15.6

# %%
# Concat baseline dataframe into result
df_mse_and_rmse = pd.concat([df_mse_and_rmse, df_result_baseline], axis=0)

# Review the result dataframe
df_mse_and_rmse.reset_index(drop=True)
# Out:
#                               Experiment  Mean MSE  Std Deviation MSE
# 0               Baseline-Raw (50 epochs)     70.07              96.53
# 1  Normalized-1 Hidden Layers(50 epochs)     50.28              60.88
# 2  Normalized-1 Hidden Layers(50 epochs)     43.05              15.60

# %% [markdown]
# ## D. Increase the number of hidden layers

# %%
max_iteration = 50
epochs = 50
verbose = 0

# Get the compiled model
model = build_model_with_three_hidden_layers(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(df_predictors_norm, 
                                            df_target, 
                                            model, 
                                            max_iteration=max_iteration, 
                                            epochs=epochs, 
                                            verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.2007529735565186
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9726855754852295
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8849258422851562
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9277732372283936
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0347826480865479
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.194643259048462
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0347316265106201
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.1411974430084229
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.184009313583374
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9214015007019043
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.893223762512207
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9382591247558594
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9286191463470459
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9042794704437256
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9213399887084961
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9549720287322998
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.1048314571380615
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9332296848297119
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8845691680908203
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9056804180145264
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9197354316711426
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9313111305236816
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0646278858184814
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.080683708190918
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9389095306396484
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9284427165985107
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9195096492767334
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9804964065551758
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.0429596900939941
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9727647304534912
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9008064270019531
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9368696212768555
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9320662021636963
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9483067989349365
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9329123497009277
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9440762996673584
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9707365036010742
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9137225151062012
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9159495830535889
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.8770244121551514
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9101805686950684
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9545364379882812
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9646427631378174
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9922528266906738
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.1023859977722168
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9445722103118896
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9217174053192139
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9192147254943848
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9472312927246094
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 0.9909088611602783
# Finished - 50 times.
# And the list of mean squared errors : [106.97537337932988, 60.55059174974563, 49.42081654003982, 44.64969852147961, 41.6018315176049, 39.868903338844255, 40.3414966438247, 40.83111631680544, 40.21466933917072, 40.96183987516942, 40.014692484253985, 40.10263144570867, 38.861017750483285, 39.27978445288024, 38.87742813063987, 39.5072044730794, 39.55133756426135, 38.542896844077944, 38.57408035120856, 37.91160467259309, 38.88466858322298, 37.1974031924776, 37.00940583495457, 36.2361084781637, 36.09469669721165, 36.7501556586054, 36.63469410017365, 36.12088607680327, 36.758640906407116, 36.11831545133016, 36.18537158008342, 36.33948289232187, 36.39942234189463, 35.345232883521, 35.286971239320124, 36.52054134819551, 35.7492783454753, 35.94883795727392, 35.514986162729556, 35.17059628533482, 34.802891840935004, 35.57579314574398, 34.78173478135052, 35.81032482468715, 35.15626704115924, 35.31468884960778, 36.467044627334054, 35.28258576105604, 34.88550753501084, 35.06334568431904]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 39.52 and 10.52, respectively

# %%
name_of_experiment = "Normalized-3 Hidden Layers(50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
df_result_baseline
# Out:
#                               Experiment  Mean MSE  Std Deviation MSE
# 0  Normalized-3 Hidden Layers(50 epochs)     39.52              10.52

# %%
# Concat baseline dataframe into result
df_mse_and_rmse = pd.concat([df_mse_and_rmse, df_result_baseline], axis=0)

# Review the result dataframe
df_mse_and_rmse.reset_index(drop=True)
# Out:
#                               Experiment  Mean MSE  Std Deviation MSE
# 0               Baseline-Raw (50 epochs)     70.07              96.53
# 1  Normalized-1 Hidden Layers(50 epochs)     50.28              60.88
# 2  Normalized-1 Hidden Layers(50 epochs)     43.05              15.60
# 3  Normalized-3 Hidden Layers(50 epochs)     39.52              10.52
